# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import plotly.express as px

# %% [markdown]
# # Google Play Store's Mobile Apps Data Analysis

# %%
df = pd.read_csv('mobileapps.csv')

# %%
df.dropna()  # Drop rows with missing values
# Out:
#                                                    App        Category
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN  \
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 145                                   Fashion in Vogue       LIFESTYLE
# 146                                               Zara       LIFESTYLE
# 147                          Wheretoget: Shop in style       LIFESTYLE
# 148                       My Dressing - Fashion closet       LIFESTYLE
# 149                                          Chictopia       LIFESTYLE
#
#      Rating  Reviews                Size     Installs  Type  Price
# ...

# %%
df.drop_duplicates() # Remove duplicates
# Out:
#                                                    App        Category
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN  \
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 142                       My Dressing - Fashion closet       LIFESTYLE
# 143                                          Chictopia       LIFESTYLE
# 144                             Scarf Fashion Designer       LIFESTYLE
# 145                                   Fashion in Vogue       LIFESTYLE
# 146                                               Zara       LIFESTYLE
#
#      Rating  Reviews                Size     Installs  Type  Price
# ...

# %% [markdown]
# The dataset used for this analysis is a CSV file containing the following columns: App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, and Android Ver. The analysis was performed using Python programming language and several data analysis and visualization libraries, including Pandas, Matplotlib, and Plotly.

# %% [markdown]
# ### Pie Chart Showing the Number of Apps per Category

# %% [markdown]
# Upon conducting a thorough analysis of mobile app data, it has been observed that the "Photography" category exhibits the lowest number of apps available on the Google Play Store. Conversely, the "Education" category boasts the highest number of mobile apps. These findings suggest that there may be a higher demand among Google Play Store users for educational apps compared to photography apps. Furthermore, this data implies that there could be a potential market gap for photography apps, presenting an opportunity for developers to explore novel and innovative app ideas in this category.

# %%
#number of apps per category using a pie chart

# group the data by 'Category' and count the number of apps in each category
apps_per_category = df['Category'].value_counts()

#o Create a pie chart
plt.figure(figsize=(15, 15)) #change the figure size

plt.pie(apps_per_category, labels=apps_per_category.index, startangle=90, counterclock=False, autopct='%1.1f%%')

# Set title and axis labels
plt.title('Number of Apps per Category')

plt.show()

# %% [markdown]
# ### Table Showing all the Mobile Apps with a Rating higher than 4.5

# %%
#all apps that are have a rating greater than 4.5
filtered_df = df[df['Rating'] > 4.5]
filtered_df
# Out:
#                                                    App             Category
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN  \
# 8                       ArtFlow: Paint Draw Sketchbook       ART_AND_DESIGN
# 10                                    Procreate Pocket       ART_AND_DESIGN
# 15                                        CityBus Lviv    AUTO_AND_VEHICLES
# 19                                            Snapseed          PHOTOGRAPHY
# 21                               Tie - Always be happy               BEAUTY
# 22                                         Ulta Beauty               BEAUTY
# 23                                Prom MakeUp Tutorial               BEAUTY
# 28                  Download free book with green book  BOOKS_AND_REFERENCE
# 64                                        Khan Academy            EDUCATION
# 65                                                 TED            EDUCATION
# ...

# %% [markdown]
# ### Table Showing all the Mobile Apps that are Paid

# %% [markdown]
# Based on a sample of 150 mobile apps, it has been observed that the only paid app among them falls under the "Photography" category. This finding suggests that among the sampled apps, the "Photography" category may have a higher tendency to offer paid apps compared to other categories. It could also indicate that developers in the "Photography" category may see potential in monetizing their apps through paid downloads, while other categories may rely more on alternative revenue models such as in-app advertisements or freemium models.

# %%
#all apps that are paid
paid_df = df[df['Price'] > 0.0]
paid_df
# Out:
#                  App        Category  Rating  Reviews Size    Installs  Type
# 10  Procreate Pocket  ART_AND_DESIGN     4.7    21567  27M  1,000,000+  Paid  \
#
#     Price Content Rating        Genres       Last Updated Current Ver
# 10   2.99       Everyone  Art & Design  December 20, 2019       1.0.1  \
#
#    Android Ver
# 10  4.3 and up

# %% [markdown]
# ### Table Showing all the Mobile Apps in the "Art and Design" Category

# %%
# filter dataFrame to only include rows with 'Category' == 'ART_AND_DESIGN'
filtered_df = df[df['Category'] == 'ART_AND_DESIGN']
filtered_df
# Out:
#                                                   App        Category  Rating
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                                    Photo Editor Pro  ART_AND_DESIGN     4.3
# 6                         SketchBook - draw and paint  ART_AND_DESIGN     4.5
# 7                          PaperColor - Coloring Book  ART_AND_DESIGN     4.2
# 8                      ArtFlow: Paint Draw Sketchbook  ART_AND_DESIGN     4.6
# 9           Color by Number - Pixel Art Coloring Book  ART_AND_DESIGN     4.4
# 10                                   Procreate Pocket  ART_AND_DESIGN     4.7
#
# ...

# %% [markdown]
# ### Table Showing all the Mobile Apps in the "Beauty" Category

# %%
# filter dataFrame to only include rows with 'Category' == 'BEAUTY'
filtered_df = df[df['Category'] == 'BEAUTY']
filtered_df
# Out:
#                            App Category  Rating  Reviews                Size
# 20          Filters for Selfie   BEAUTY     4.3     8572                 25M  \
# 21       Tie - Always be happy   BEAUTY     4.7      964                9.0M
# 22                 Ulta Beauty   BEAUTY     4.7    42050  Varies with device
# 23        Prom MakeUp Tutorial   BEAUTY     4.8      104                 12M
# 24               Selfie Camera   BEAUTY     4.2    17934  Varies with device
# 25  Sweet Selfie Beauty Camera   BEAUTY     4.3      601                 35M
# 26     Colors of white in Urdu   BEAUTY     4.5       36                6.7M
#
#       Installs  Type  Price Content Rating  Genres        Last Updated
# 20  1,000,000+  Free    0.0       Everyone  Beauty        May 10, 2018  \
# 21     50,000+  Free    0.0       Everyone  Beauty       June 21, 2018
# 22  1,000,000+  Free    0.0       Everyone  Beauty        June 5, 2018
# ...

# %% [markdown]
# ### Table Showing all the Mobile Apps in the "Photography" Category

# %%
# filter dataFrame to only include rows with 'Category' == 'PHOTOGRAPHY'
filtered_df = df[df['Category'] == 'PHOTOGRAPHY']
filtered_df
# Out:
#                                                   App     Category  Rating
# 16  Adobe Photoshop Express:Photo Editor Collage M...  PHOTOGRAPHY     4.3  \
# 17    PicsArt Photo Editor: Pic Video & Collage Maker  PHOTOGRAPHY     4.5
# 18  Camera360: Selfie Photo Editor with Funny Sticker  PHOTOGRAPHY     4.4
# 19                                           Snapseed  PHOTOGRAPHY     4.6
#
#     Reviews Size      Installs  Type  Price Content Rating       Genres
# 16  1046789  59M  100,000,000+  Free    0.0       Everyone  Photography  \
# 17  9872345  44M  500,000,000+  Free    0.0       Everyone  Photography
# 18   567890  72M  100,000,000+  Free    0.0           Teen  Photography
# 19  2345678  28M  100,000,000+  Free    0.0       Everyone  Photography
#
#       Last Updated       Current Ver Android Ver
# 16    May 14, 2020           7.5.858  5.0 and up
# 17  April 28, 2020            17.9.2  5.0 and up
# 18   March 1, 2020             9.9.6  4.4 and up
# ...

# %% [markdown]
# ### Table Showing all the Mobile Apps in the "Education" Category with a Rating of 4.5 and above

# %%
# filter dataFrame to only include rows with 'Category' == 'EDUCATION' and a rating of 4.5 and above
filtered_df = df[(df['Category'] == 'EDUCATION') & (df['Rating'] > 4.5)]
filtered_df
# Out:
#                                                   App   Category  Rating
# 64                                       Khan Academy  EDUCATION     4.6  \
# 65                                                TED  EDUCATION     4.6
# 66   Quizlet: Learn Languages & Vocab with Flashcards  EDUCATION     4.6
# 69        edX - Online Courses by Harvard, MIT & more  EDUCATION     4.6
# 80                     Duolingo: Learn Languages Free  EDUCATION     4.7
# 86  Learn languages, grammar & vocabulary with Mem...  EDUCATION     4.7
#
#     Reviews                Size      Installs  Type  Price Content Rating
# 64    85375                 21M    5,000,000+  Free    0.0       Everyone  \
# 65   181893                 18M   10,000,000+  Free    0.0   Everyone 10+
# 66   211856  Varies with device   10,000,000+  Free    0.0       Everyone
# 69    32381                 10M    1,000,000+  Free    0.0   Everyone 10+
# 80  6290507  Varies with device  100,000,000+  Free    0.0       Everyone
# ...

# %% [markdown]
# ### Table Showing all the Mobile Apps in the "Education" Category with a Rating of 4.5 and above

# %%
# filter dataFrame to only include rows with 'Category' == 'ENTERTAINMENT' and a rating of 4.5 and above
filtered_df = df[(df['Category'] == 'ENTERTAINMENT') & (df['Rating'] > 4.0)]
filtered_df
# Out:
#                                                  App       Category  Rating
# 88                                      AMC Theatres  ENTERTAINMENT     4.3  \
# 89                                  IMDb Movies & TV  ENTERTAINMENT     4.2
# 90                                           Netflix  ENTERTAINMENT     4.4
# 91                                      Food Network  ENTERTAINMENT     4.1
# 92                                   Cooking Channel  ENTERTAINMENT     4.1
# 93                                  Animal Planet GO  ENTERTAINMENT     4.2
# 95     DramaFever: Stream Asian Drama Shows & Movies  ENTERTAINMENT     4.2
# 97                        Investigation Discovery GO  ENTERTAINMENT     4.5
# 100                                            STARZ  ENTERTAINMENT     4.3
# 102  HISTORY: Watch TV Show Full Episodes & Specials  ENTERTAINMENT     4.1
# 103                                             Nick  ENTERTAINMENT     4.2
#
# ...

# %% [markdown]
# ### Table Showing all the Mobile Apps with the highest to lowest ratings

# %%
#in ascending order, sorts all the items by rating
sorted_df = df.sort_values('Rating', ascending=False)
sorted_df
# Out:
#                                                    App            Category
# 23                                Prom MakeUp Tutorial              BEAUTY  \
# 136                           Couch to 5K by RunDouble  HEALTH_AND_FITNESS
# 10                                    Procreate Pocket      ART_AND_DESIGN
# 126                                  Delicious Recipes      FOOD_AND_DRINK
# 21                               Tie - Always be happy              BEAUTY
# ..                                                 ...                 ...
# 39   comico Popular Original Cartoon Updated Everyd...              COMICS
# 40                       Daily Manga - Comic & Webtoon              COMICS
# 101   Acorn TV: World-class TV from Britain and Beyond       ENTERTAINMENT
# 121                              Easy and Fast Recipes      FOOD_AND_DRINK
# 124           Sumine side dish - dish recipe side dish      FOOD_AND_DRINK
#
#      Rating  Reviews                Size    Installs  Type  Price
# ...

# %% [markdown]
# ### Table Showing the Max Number of Installs for Each Category

# %% [markdown]
# The mobile apps data reveals the varying levels of installations for different categories of mobile apps on the Google Play Store. The "COMMUNICATION" category stands out with the highest number of installs, totaling over 500 million, indicating a significant demand for business-related apps. On the other hand, categories such as "AUTO_AND_VEHICLES", "BEAUTY", and "BOOKS_AND_REFERENCE" have relatively lower installations, with 50,000+ installs each, suggesting lesser popularity among users. Interestingly, the "PHOTOGRAPHY" category, also has more than 500 million installs, despite having the least amount of mobile apps in Play Store.

# %%
#groups the apps by category then shows the max number of installs for each
grouped_by_category = df.groupby('Category')
max_installs_by_category = grouped_by_category['Installs'].max()
max_installs_by_category
# Out:
# Category
# ART_AND_DESIGN             500,000+
# AUTO_AND_VEHICLES           50,000+
# BEAUTY                      50,000+
# BOOKS_AND_REFERENCE         50,000+
# BUSINESS                50,000,000+
# COMICS                   5,000,000+
# COMMUNICATION          500,000,000+
# DATING                     100,000+
# EDUCATION                  500,000+
# ENTERTAINMENT              500,000+
# FINANCE                    500,000+
# FOOD_AND_DRINK             500,000+
# HEALTH_AND_FITNESS       5,000,000+
# LIFESTYLE                  500,000+
# PHOTOGRAPHY            500,000,000+
# Name: Installs, dtype: object

# %% [markdown]
# ### Table Showing the Mean Rating for Each Category

# %% [markdown]
# The average ratings for free apps in most categories range from 4.0 to 4.5, indicating generally positive user satisfaction. However, the "ART_AND_DESIGN" category stands out with both free and paid apps having higher average ratings of 4.4 and 4.7 respectively, suggesting that users may be willing to pay for higher-rated apps in this category.

# %%
#groups the apps by category and type then shows the mean number of ratings for each
grouped_by_category_and_type = df.groupby(['Category', 'Type'])
mean_rating_by_category_and_type = grouped_by_category_and_type['Rating'].mean()

# Round to one decimal place
mean_rating_by_category_and_type = mean_rating_by_category_and_type.round(1)

mean_rating_by_category_and_type
# Out:
# Category             Type
# ART_AND_DESIGN       Free    4.4
#                      Paid    4.7
# AUTO_AND_VEHICLES    Free    4.2
# BEAUTY               Free    4.5
# BOOKS_AND_REFERENCE  Free    4.4
# BUSINESS             Free    4.2
# COMICS               Free    3.9
# COMMUNICATION        Free    4.3
# DATING               Free    4.0
# EDUCATION            Free    4.4
# ENTERTAINMENT        Free    4.0
# FINANCE              Free    4.4
# FOOD_AND_DRINK       Free    4.3
# HEALTH_AND_FITNESS   Free    4.5
# LIFESTYLE            Free    4.2
# PHOTOGRAPHY          Free    4.4
# Name: Rating, dtype: float64

# %% [markdown]
# ### Bar Graph Showing the Number of Installs Per Category

# %% [markdown]
# Upon analyzing the mobile app data, it is evident that apps in all categories have installations exceeding 500 million. However, the "Communication" category stands out with a staggering 1 billion installs, indicating its widespread popularity among users. This data suggests that communication-related apps are in high demand, potentially due to the increasing reliance on mobile communication in today's digital age. It also highlights the significant market potential for developers and businesses in the communication app space. Other categories may also have substantial installations, but the "Communication" category leads the pack with the highest number of installs among the categories analyzed.

# %%
#stores the columns in variables
app_names = df['Category']
reviews = df['Installs']

# makes the bar graph
plt.bar(app_names, reviews, color = "green")

# convert 'Installs' column to string
df['Installs'] = df['Installs'].astype(str)

# remove the plus sign from 'Installs' column
df['Installs'] = df['Installs'].str.replace('+', '')

# remove commas from 'Installs' column (if present)
df['Installs'] = df['Installs'].str.replace(',', '')

# convert 'Installs' column to integer
df['Installs'] = df['Installs'].astype(int)

# customizes appearance
plt.xlabel('Category')
plt.ylabel('Number of Installs')
plt.title('Bar Graph Showing the Number of Installs Per Category')
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Table Showing the Top Ten Mobile Apps Based on Number of Reviews

# %% [markdown]
# As evident from the table, the top three apps with the highest number of reviews all belong to the "Communication" category. It was also discovered that three other mobile apps are from the Communication category. This observation underscores the high demand for communication apps in today's society. The significant number of reviews indicates that these apps are widely used and have garnered substantial user engagement. This trend emphasizes the central role of communication apps in connecting people and facilitating communication in today's digital world.
#
# Furthermore, in addition to the communication apps, it is worth noting that two photography apps also rank among the highest in terms of reviews. This suggests that photography apps are also popular among users and have generated significant user engagement.
#
# In addition, Duolingo was seen to have one of the most reviews on the google app store. This is probably due to
# the high demand for language learning apps in today's society. Duolingo, being a prominent player in the education category, has likely gained significant traction and garnered a large number of reviews due to its effective language learning features and user-friendly interface.
#
# Lastly, it is noteworthy that Netflix, a well-known streaming platform for movies and television series, is also included among the mobile apps with the highest number of reviews. This can be attributed to the widespread popularity of Netflix as a leading streaming service, catering to a global audience.

# %%
top_10_apps = df.nlargest(10, 'Reviews')  # Select top 10 apps by reviews
top_10_apps
# Out:
#                                                 App       Category  Rating
# 47                               WhatsApp Messenger  COMMUNICATION     4.4  \
# 46         Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 53                                  Viber Messenger  COMMUNICATION     4.3
# 17  PicsArt Photo Editor: Pic Video & Collage Maker    PHOTOGRAPHY     4.5
# 49                     Google Chrome: Fast & Secure  COMMUNICATION     4.3
# 80                   Duolingo: Learn Languages Free      EDUCATION     4.7
# 90                                          Netflix  ENTERTAINMENT     4.4
# 51                                            Gmail  COMMUNICATION     4.3
# 52                                         Hangouts  COMMUNICATION     4.0
# 19                                         Snapseed    PHOTOGRAPHY     4.6
#
#      Reviews                Size    Installs  Type  Price Content Rating
# ...

# %% [markdown]
# ### Bar Chart Showing the Top Ten Apps by Number of Reviews in the Google Play Store

# %%
top_10_apps = df.nlargest(10, 'Reviews') 
top_10_apps_names = top_10_apps['App']  # Get the names of the top 10 apps
top_10_apps_reviews = top_10_apps['Reviews']

# Plot a bar graph of top 10 apps by ratings
plt.bar(top_10_apps_names, top_10_apps_reviews, color="green")
plt.xlabel('App')
plt.ylabel('Number of Reviews (x 10,000,000)')
plt.title('Top 10 Apps by Number of Reviews')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### The Most Popular App with the Most Reviews is Whatsapp Messenger

# %%
top_app = df.nlargest(1, 'Reviews') 
top_app
# Out:
#                    App       Category  Rating   Reviews                Size
# 47  WhatsApp Messenger  COMMUNICATION     4.4  69119316  Varies with device  \
#
#       Installs  Type  Price Content Rating         Genres    Last Updated
# 47  1000000000  Free    0.0       Everyone  Communication  August 3, 2018  \
#
#            Current Ver         Android Ver
# 47  Varies with device  Varies with device

# %% [markdown]
# ### The Mobile App with the most Installations

# %%
#filters the dataframe to collect the photography apps
filtered_df = df[df['Category'] == 'PHOTOGRAPHY']

#sorts the filtered list by number of installs in ascending order
# uses head() to get the first value in the data fram
top_app = filtered_df.sort_values(by='Installs', ascending=False).head(1)

top_app
# Out:
#                                                 App     Category  Rating
# 17  PicsArt Photo Editor: Pic Video & Collage Maker  PHOTOGRAPHY     4.5  \
#
#     Reviews Size   Installs  Type  Price Content Rating       Genres
# 17  9872345  44M  500000000  Free    0.0       Everyone  Photography  \
#
#       Last Updated Current Ver Android Ver
# 17  April 28, 2020      17.9.2  5.0 and up

# %% [markdown]
# ### Table Showing the Last Updated Mobile Apps

# %%
#sort by date last updated

# convert "Last Updated" column to datetime object
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

## sort the dataFrame by "Last Updated" column in descending order
df = df.sort_values(by='Last Updated', ascending=True)
df
# Out:
#                                                    App             Category
# 149                                          Chictopia            LIFESTYLE  \
# 143                                          Chictopia            LIFESTYLE
# 13                                   Restart Navigator    AUTO_AND_VEHICLES
# 31                                         Cool Reader  BOOKS_AND_REFERENCE
# 145                                   Fashion in Vogue            LIFESTYLE
# ..                                                 ...                  ...
# 6                          SketchBook - draw and paint       ART_AND_DESIGN
# 17     PicsArt Photo Editor: Pic Video & Collage Maker          PHOTOGRAPHY
# 16   Adobe Photoshop Express:Photo Editor Collage M...          PHOTOGRAPHY
# 8                       ArtFlow: Paint Draw Sketchbook       ART_AND_DESIGN
# 19                                            Snapseed          PHOTOGRAPHY
#
# ...

# %% [markdown]
# ### Pie Chart Showing the Number of Paid Apps compared to Free Apps

# %% [markdown]
# The prevalence of free apps in the app store can be attributed to user expectations and the highly competitive nature of the app market. Many users expect apps to be available for free, as there are numerous free apps already available in the market. In order to attract a larger user base and generate revenue, developers often offer apps for free and monetize them through other means such as in-app purchases, advertisements, or subscriptions.

# %%
free_df = df[df['Price'] == 0.0] #stores free apps
paid_df = df[df['Price'] > 0.0] #stores paid apps

# create data for the pie chart
labels = ['Paid Apps', 'Free Apps']
sizes = [len(paid_df), len(free_df)]
colors = ['blue', 'green']

# create a pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Paid Apps vs. Free Apps')

# show the pie chart
plt.show()

# %% [markdown]
# ### Bar Graph Showing the Number of Apps per Content Rating

# %% [markdown]
# As seen in the bar graph, the content rating with the most apps are rated for "Everyone". Apps that target a broad audience are more prevalent in the play store due to their potential for a larger user base and higher market demand. These apps typically cater to common needs or interests shared by a wide range of users, such as communication, education, entertainment, and lifestyle. Developers often prioritize these popular categories to maximize their app's reach and potential for success in the competitive app market.

# %%
#stores the different content ratings that exist
content_ratings = df['Content Rating'].value_counts()

# Create a bar chart
plt.bar(content_ratings.index, content_ratings.values, color='green', width=0.3)
plt.title('Number of Apps per Content Rating')
plt.xlabel('Content Rating')
plt.ylabel('Number of Apps')

# Show the bar chart
plt.show()
